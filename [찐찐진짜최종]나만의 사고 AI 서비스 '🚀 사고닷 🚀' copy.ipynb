# %% [markdown]
# # 나만의 사고 AI 서비스 '🚀 사고닷 🚀'
# 사고 관련 법률 상담을 AI를 활용하여 자동화하고,
# 단계별 질문을 통해 사용자 맞춤형 법률 정보를 제공

# %%
# !pip install --upgrade jsonlines openai langchain langchain-openai langchain-community beautifulsoup4 langchain_chroma chromadb==0.5.3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jsonlines in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (4.0.0)
# Requirement already satisfied: openai in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (1.65.4)
# Requirement already satisfied: langchain in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (0.3.20)
# Requirement already satisfied: langchain-openai in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (0.3.7)
# Requirement already satisfied: langchain-community in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (0.3.19)
# Requirement already satisfied: beautifulsoup4 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (4.13.3)
# Requirement already satisfied: langchain_chroma in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (0.2.2)
# Requirement already satisfied: chromadb==0.5.3 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (0.5.3)
# Requirement already satisfied: build>=1.0.3 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (1.2.2.post1)
# Requirement already satisfied: requests>=2.28 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (2.32.3)
# Requirement already satisfied: pydantic>=1.9 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (2.10.6)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (0.115.11)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.3) (0.34.0)
# Requirement already satisfied: numpy<2.0.0,>=1.22.5 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (3.18.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (1.30.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (1.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (0.51b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (1.30.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (0.21.0)
# Requirement already satisfied: pypika>=0.48.9 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (1.70.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (0.15.2)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from chromadb==0.5.3) (0.28.1)
# Requirement already satisfied: attrs>=19.2.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from jsonlines) (25.1.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from openai) (0.8.2)
# Requirement already satisfied: sniffio in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from openai) (1.3.1)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.41 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from langchain) (0.3.41)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from langchain) (0.3.6)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from langchain) (0.3.11)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from langchain) (2.0.38)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from langchain-community) (3.11.13)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from langchain-community) (2.8.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: packaging>=19.1 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from build>=1.0.3->chromadb==0.5.3) (24.2)
# Requirement already satisfied: pyproject_hooks in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from build>=1.0.3->chromadb==0.5.3) (1.2.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from build>=1.0.3->chromadb==0.5.3) (8.5.0)
# Requirement already satisfied: tomli>=1.1.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from build>=1.0.3->chromadb==0.5.3) (2.2.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from fastapi>=0.95.2->chromadb==0.5.3) (0.46.0)
# Requirement already satisfied: certifi in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from httpx>=0.27.0->chromadb==0.5.3) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from httpx>=0.27.0->chromadb==0.5.3) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb==0.5.3) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (0.9)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: coloredlogs in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.3) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.3) (25.2.10)
# Requirement already satisfied: protobuf in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.3) (5.29.3)
# Requirement already satisfied: sympy in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from onnxruntime>=1.14.1->chromadb==0.5.3) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from opentelemetry-api>=1.2.0->chromadb==0.5.3) (1.2.18)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.3) (1.69.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.30.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.3) (1.30.0)
# Requirement already satisfied: opentelemetry-proto==1.30.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.3) (1.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.51b0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.51b0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (0.51b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (0.51b0)
# Requirement already satisfied: opentelemetry-util-http==0.51b0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (0.51b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from opentelemetry-instrumentation==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from opentelemetry-instrumentation-asgi==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from posthog>=2.4.0->chromadb==0.5.3) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from posthog>=2.4.0->chromadb==0.5.3) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from pydantic>=1.9->chromadb==0.5.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from pydantic>=1.9->chromadb==0.5.3) (2.27.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from requests>=2.28->chromadb==0.5.3) (3.4.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from tokenizers>=0.13.2->chromadb==0.5.3) (0.29.1)
# Requirement already satisfied: click>=8.0.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from typer>=0.9.0->chromadb==0.5.3) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from typer>=0.9.0->chromadb==0.5.3) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from typer>=0.9.0->chromadb==0.5.3) (13.9.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.3) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.3) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.3) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.3) (12.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from importlib-resources->chromadb==0.5.3) (3.21.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.3) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.3) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.3) (4.9)
# Requirement already satisfied: filelock in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.5.3) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.5.3) (2025.2.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.41->langchain) (3.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.5.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.5.3) (2.19.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.5.3) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.5.3) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb==0.5.3) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.3) (0.6.1)

# %%
# !pip install pymupdf sentence-transformers faiss-cpu
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pymupdf in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (1.25.3)
# Requirement already satisfied: sentence-transformers in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (3.4.1)
# Requirement already satisfied: faiss-cpu in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (1.10.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (4.49.0)
# Requirement already satisfied: tqdm in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: scikit-learn in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (0.29.1)
# Requirement already satisfied: Pillow in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: filelock in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.2.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.5)
# Requirement already satisfied: sympy==1.13.1 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/now_ung/Library/Python/3.9/lib/python/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.1.31)

# %%
import requests
from bs4 import BeautifulSoup
import os

#os.environ["OPENAI_API_KEY"] = "<OpenAI_API의 API 키>"
os.environ["OPENAI_API_KEY"] = "YOUR_KEY"

os.environ['USER_AGENT']='MyCustomAgent'
# 아래 코드 Warning 제거

# %%
import fitz  # PyMuPDF 라이브러리

def extract_text_from_pdf(pdf_path):
    text = ""
    doc = fitz.open(pdf_path)  # PDF 열기
    for page in doc:
        text += page.get_text("text") + "\n"
    return text

# 저장된 PDF 파일들 처리
pdf_folder = "pdf_files"
pdf_texts = {}

for pdf_file in os.listdir(pdf_folder):
    pdf_path = os.path.join(pdf_folder, pdf_file)
    text = extract_text_from_pdf(pdf_path)
    pdf_texts[pdf_file] = text
    print(f"텍스트 추출 완료: {pdf_file}")
# Out:
# 텍스트 추출 완료: 한글 6법전(헌법, 민법, 형법, 상법, 민사소송법, 형사소송법).pdf
# 텍스트 추출 완료: 한글 4법전(헌법, 민법, 형법, 형사소송법).pdf

# %%
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer

# 임베딩 모델 로드 (빠르고 가벼운 모델)
model = SentenceTransformer("all-MiniLM-L6-v2")

# 벡터 변환
pdf_embeddings = {}
for pdf_file, text in pdf_texts.items():
    embedding = model.encode(text)
    pdf_embeddings[pdf_file] = embedding
    print(f"벡터 변환 완료: {pdf_file}")

# FAISS 벡터 DB 생성
embedding_dim = len(next(iter(pdf_embeddings.values())))  # 벡터 차원
index = faiss.IndexFlatL2(embedding_dim)  

# 벡터 삽입
pdf_files = list(pdf_embeddings.keys())
pdf_vectors = np.array(list(pdf_embeddings.values()), dtype="float32")
index.add(pdf_vectors)

# FAISS 인덱스 저장
faiss.write_index(index, "faiss_index.bin")
np.save("pdf_files.npy", np.array(pdf_files))  # PDF 파일명 저장

print("FAISS DB 저장 완료 ✅")
# Out:
# 벡터 변환 완료: 한글 6법전(헌법, 민법, 형법, 상법, 민사소송법, 형사소송법).pdf
# 벡터 변환 완료: 한글 4법전(헌법, 민법, 형법, 형사소송법).pdf
# FAISS DB 저장 완료 ✅

# %%
import os
from openai import OpenAI
from langchain_openai import ChatOpenAI
from langchain_community.retrievers import TavilySearchAPIRetriever
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain.schema import Document


# OpenAI 클라이언트 연결
client = OpenAI(api_key="YOUR_KEY")
os.environ["TAVILY_API_KEY"] = "JINSIL'S_KEY"


class Agent:
    def __init__(self, system_prompt=""):
        self.system_prompt = system_prompt
        self.messages = [{"role": "system", "content": system_prompt}]  # 초기 프롬프트 포함
        self.user_queries = []

    def __call__(self, message):
        """사용자의 입력을 받아 AI 응답을 생성"""
        self.messages.append({"role": "user", "content": message})
        self.user_queries.append(message)

        result = self.execute()
        self.messages.append({"role": "assistant", "content": result})
        return result

    def execute(self):
        """AI에게 메시지를 보내고 응답을 받음"""
        completion = client.chat.completions.create(
            model="gpt-4o-mini",
            temperature=0,
            messages=self.messages
        )
        return completion.choices[0].message.content

    def summarize_conversation(self):
        """사용자 상담 내용을 한 문장으로 요약"""
        summary_prompt = f"""
        다음 사용자의 질문을 한 문장으로 요약하세요: {self.user_queries}
        """
        print(self.user_queries)
        
        completion = client.chat.completions.create(
            model="gpt-4o-mini",
            temperature=0,
            messages=[{"role": "system", "content": "대화 내용을 한 문장으로 요약하는 역할을 수행합니다."},
                      {"role": "user", "content": summary_prompt}]
        )
        return completion.choices[0].message.content
    

# **시스템 프롬프트 (단계별 상담 + 가이드라인 유지)**
prompt = """
당신은 사고 관련 법률 정보를 제공하는 AI 법률 상담사입니다.
사용자가 사고와 관련된 법률적 도움을 요청할 때, 아래의 단계별 질문 프레임워크를 따라 포괄적인 질문에서 구체적인 질문으로 진행하며 정확한 법률 정보를 제공해야 합니다.

# 시스템 지침
1. 사용자의 첫 질문이나 문의를 들은 후, 단계별로 질문을 진행하세요.
2. 각 단계마다 답변을 듣고 그에 맞는 다음 단계의 질문을 선택하세요.
3. 사용자의 응답에 따라 관련 법률 정보와 조언을 제공하세요.
4. 모든 법률 정보는 정확하고 최신의 정보여야 합니다.
5. 전문적이지만 이해하기 쉬운 언어로 소통하세요.
6. 사용자가 추가 질문이나 명확한 설명을 요청할 경우, 즉시 응답하세요.
7. 법률적 조언이 필요한 경우 실제 변호사와 상담할 것을 권장하세요.

# 응답 가이드라인
1. 사용자의 응답이 불분명하거나 부족한 경우, 추가 질문을 통해 명확히 하세요.
2. 사용자가 질문 단계를 건너뛰거나 다른 주제로 전환하려 할 경우, 필요한 정보를 얻기 위해 질문을 다시 유도하세요.
3. 사용자가 특정 법률 용어나 절차에 대해 이해하지 못하는 경우, 이해하기 쉽게 설명해주세요.
4. 유사한 판례나 법률 조항을 인용할 때는 정확한 출처와 내용을 제공하세요.
5. 모든 정보와 조언은 객관적이고 사실에 기반해야 합니다.
6. 사용자의 감정적 상태를 고려하여 공감적인 태도를 유지하세요.
7. 사용자의 상황이 긴급하거나 심각한 경우, 적절한 긴급 조치나 전문가 상담을 권장하세요.

# 질문 프로세스
1. Thought: 질문을 분석하여 어떤 정보를 더 수집해야 하는지 결정하세요.
2. Action: 필요한 정보를 얻기 위한 질문을 생성하세요.
3. 사용자 응답 후 다음 단계로 진행하세요.
"""

# AI 상담 Agent 생성
abot = Agent(system_prompt=prompt)

# 🔹 Tavily 검색 관련 설정
def search_law_cases(query):
    """Tavily에서 실제 판례 기사 검색 및 요약"""
    tavily = TavilySearchResults()
    result = tavily.invoke(query)

    # 검색 결과를 하나의 문서로 정리
    full_content = ""
    for item in result:
        full_content += f"📌 **{item['title']}**\n"
        full_content += f"{item['content']}\n"
        full_content += f"[🔗 링크]({item['url']})\n\n"

    return full_content

def format_docs(docs):
    """Tavily 검색 결과를 정리하는 함수"""
    formatted_docs = ""
    for d in docs:
        # d.page_content는 텍스트 내용, d.metadata에 URL이 포함되어 있을 수 있습니다.
        formatted_docs += f"Content: {d.page_content}\n"  # 문서 내용
        if hasattr(d, 'metadata') and 'source' in d.metadata:
            formatted_docs += f"URL: {d.metadata['source']}\n"  # 문서 URL
        formatted_docs += "\n"  # 항목 간 구분
    return formatted_docs

# 🔹 Tavily 검색을 위한 LLM 프롬프트
template = """Answer the question based only on the following context:

{context}

Question: {question}

사용자에게 얻은 정보에 따라 웹을 검색하고, 검색된 사건 관련 법률 정보와 사례를 아래 형식에 맞게 정리하여 답변을 생성해주세요.
<법률 정보>
법률 제목: 절도에 관한 형법
법률 조항: "타인의 재산을 불법적으로 취득한 경우, 절도로 간주되어 형사 처벌을 받을 수 있습니다."
법률 요약: 절도는 타인의 재산을 불법적으로 취득하는 행위로, 이 법은 절도의 정의 및 처벌 내용을 명시하고 있습니다.
법률 제목: 형법 제329조 (절도)
법률 조항: "절도의 경우, 피해 금액에 따라 처벌이 달라지며, 피해자가 10만원 이상을 잃은 경우 형사 처벌을 받게 됩니다."
법률 요약: 이 법은 절도의 처벌 기준을 정하며, 금액에 따라 다르게 처벌됩니다. 특히, 절도 금액이 10만원 이상일 경우, 형사 처벌이 부과됩니다.
<관련 사례>
사례 제목: 서울 절도 사건 배상 책임 사례
사례 요약: "2020년에 발생한 서울의 한 절도 사건에서, 피고인은 50만원 규모의 절도로 유죄 판결을 받았으며, 금전적 배상 및 징역형을 선고받았습니다."
링크: 외부로부터 받아오는 문서의 'URL' 정보를 링크로 달아주세요.
사례 제목: 절도 사건의 판결: 피해자 배상 사례
사례 요약: "2019년 발생한 절도 사건에서, 피해자는 가해자에게 법적 배상을 청구했습니다. 법원은 피해 금액을 기준으로 배상액을 산정하며, 피해자가 입은 피해를 보상받게 했습니다."
링크: 외부로부터 받아오는 문서의 'URL' 정보를 링크로 달아주세요.
사례 제목: 절도 사건의 합의 판결 사례
사례 요약: "2021년에 발생한 절도 사건에서, 피해자는 가해자와 합의를 통해 금전적 배상금을 받기로 했으며, 법원은 그 합의를 인정하여 사건을 종결했습니다."
링크: 외부로부터 받아오는 문서의 'URL' 정보를 링크로 달아주세요.
<예상 결과>
승률: "절도 사건의 승률은 피해 금액과 증거에 따라 다르며, 현 상황에서는 50만원 규모의 절도로 유죄 판결을 받을 것으로 예상됩니다.."
형량: "형량은 범죄의 심각성과 피해 금액에 따라 다르며, 일반적으로 금전적 배상과 함께 형사 처벌이 부과됩니다."
소요 기간: "절도 사건의 경우 보통 3개월에서 6개월 정도 소요될 수 있으며, 피해자가 법적 배상을 청구한 경우 기간이 더 길어질 수 있습니다.">
"""
prompt_template = ChatPromptTemplate.from_template(template)
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
retriever = TavilySearchAPIRetriever(k=3, search_depth="advanced", include_domains=["news"])

chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt_template
    | llm
)


def interactive_law_consultation():
    """사용자가 질문하면 AI가 단계별 질문을 진행하며 정보를 수집"""
    print("\n[나만의 사고 AI 서비스 '🚀 사고닷 🚀' 법률 상담 챗봇] 상담을 시작합니다. (종료하려면 'exit' 입력)\n")

    # 초기 사용자 질문 입력
    while True:
        user_query = input("사용자: ")

        if user_query.lower() == "exit":
            print("\n[🚀 사고닷 🚀] 상담을 종료합니다.")
            
            # 🔹 사용자 상담 내용을 요약하여 Tavily 검색 수행
            summary = abot.summarize_conversation()
            print("\n🚀 상담 요약:", summary)

            # 🔹 Tavily 검색 실행
            law_search_result = search_law_cases(f"{summary} 관련 실제 판례 기사 내용")
            print("\n🔎 검색된 법률 정보:\n", law_search_result)

            # 🔹 검색된 내용을 Tavily AI로 요약
            ai_search_result = chain.invoke(f"{summary} 관련 형량이나 벌금 정보")
            print("\n📜 Tavily AI 검색 요약:\n", ai_search_result.content)

            break

        ai_response = abot(user_query)
        print("\n🚀 사고닷 🚀 : ", ai_response)


# **실행**
interactive_law_consultation()
# Out:
# [나만의 사고 AI 서비스 '🚀 사고닷 🚀' 법률 상담 챗봇] 상담을 시작합니다. (종료하려면 'exit' 입력)
#
#
# 🚀 사고닷 🚀 :  전세 사기를 당하셨다니 매우 안타깝습니다. 이 문제를 해결하기 위해 몇 가지 질문을 드리겠습니다.
#
# 첫 번째로, 전세 사기를 당한 상황에 대해 좀 더 구체적으로 말씀해 주실 수 있나요? 예를 들어, 어떤 방식으로 사기를 당하셨는지, 계약서가 있었는지, 그리고 현재 어떤 조치를 취하고 계신지 알려주시면 좋겠습니다.
#
# 🚀 사고닷 🚀 :  주인과 연락이 되지 않아 보증금을 돌려받지 못하는 상황이시군요. 이 경우, 몇 가지 추가 질문을 통해 상황을 더 명확히 파악해 보겠습니다.
#
# 1. 계약서에는 보증금 반환에 대한 조항이 어떻게 되어 있나요?
# 2. 주인과의 연락이 끊어진 지 얼마나 되었나요?
# 3. 주인의 연락처 외에 다른 방법으로 연락을 시도해 보셨나요? (예: 친구나 가족을 통해, 또는 주인의 주소로 편지를 보내는 등)
# 4. 전세 계약이 언제 종료되었는지, 그리고 보증금 반환 기한이 있었는지 알려주실 수 있나요?
#
# 이 정보를 통해 더 구체적인 조언을 드릴 수 있을 것 같습니다.
#
# 🚀 사고닷 🚀 :  좋습니다. 전세 계약서의 보증금 반환 조항은 매우 중요합니다. 일반적으로 계약서에는 다음과 같은 내용이 포함되어야 합니다:
#
# 1. **보증금 반환 시기**: 계약 종료 후 보증금을 언제 반환해야 하는지 명시되어 있어야 합니다. 예를 들어, "계약 종료 후 30일 이내에 보증금을 반환한다"는 식으로요.
#
# 2. **보증금 반환 조건**: 보증금을 반환하기 위한 조건이 명시되어 있을 수 있습니다. 예를 들어, "세입자가 집을 원상복구한 경우" 또는 "세입자가 계약을 성실히 이행한 경우"와 같은 조건이 있을 수 있습니다.
#
# 3. **연락처 및 통지 방법**: 보증금을 반환하기 위해 주인에게 연락할 때 어떤 방법으로 통지해야 하는지에 대한 내용이 있을 수 있습니다. 예를 들어, "서면으로 통지해야 한다"는 조항이 있을 수 있습니다.
#
# 4. **위약금 조항**: 만약 주인이 보증금을 반환하지 않을 경우, 세입자가 취할 수 있는 조치나 위약금에 대한 내용이 포함될 수 있습니다.
#
# 계약서의 이러한 조항들이 어떻게 되어 있는지 확인해 보시고, 그에 따라 주인에게 연락을 시도하거나 법적 조치를 고려할 수 있습니다.
#
# 계약서의 내용을 바탕으로 어떤 조치를 취할 수 있을지 더 구체적으로 안내해 드릴 수 있으니, 계약서의 보증금 반환 조항에 대해 알려주실 수 있나요?
#
# 🚀 사고닷 🚀 :  전세 사기와 관련된 범죄는 주로 사기죄로 분류되며, 이 경우 가해자는 형사처벌을 받을 수 있습니다. 한국의 형법에 따르면 사기죄는 다음과 같은 처벌을 받을 수 있습니다:
#
# 1. **사기죄의 정의**: 타인을 기망하여 재산상의 이익을 취득하는 행위입니다. 전세 사기는 주로 임대차 계약을 통해 발생하므로, 계약의 내용이 허위이거나 기망이 있을 경우 사기죄에 해당합니다.
#
# 2. **처벌 수위**: 사기죄는 10년 이하의 징역형 또는 2천만 원 이하의 벌금에 처해질 수 있습니다. 피해 금액이 크거나 범행이 악질적일 경우, 처벌이 더 무거워질 수 있습니다.
#
# 3. **가중처벌**: 만약 가해자가 여러 명의 피해자를 대상으로 사기를 저질렀다면, 처벌이 가중될 수 있습니다. 또한, 피해자가 고령자이거나 장애인인 경우에도 가중처벌이 적용될 수 있습니다.
#
# 4. **민사적 책임**: 형사처벌 외에도, 피해자는 가해자에게 손해배상을 청구할 수 있습니다. 이 경우, 피해자가 입은 손해를 입증해야 하며, 법원에서 손해배상 판결을 받을 수 있습니다.
#
# 전세 사기 피해를 당하셨다면, 경찰에 신고하고 법적 조치를 취하는 것이 중요합니다. 또한, 변호사와 상담하여 구체적인 법적 절차를 안내받는 것도 좋은 방법입니다. 추가로 궁금한 점이 있으시면 말씀해 주세요.
#
# [🚀 사고닷 🚀] 상담을 종료합니다.
# ['전세 사기를 당했어', '이제 방을 빼야 하는데 주인집에서 보증금을 돌려줘야하는데 연락이 되지 않아', '1번에 대해 자세하게 답변해줘', '혹시 전세사기 가해자가 처벌을 얼마나 받을 수 있어?']
#
# 🚀 상담 요약: 사용자는 전세 사기를 당해 보증금을 돌려받지 못하고 있으며, 가해자의 처벌에 대해 궁금해하고 있다.
#
# 🔎 검색된 법률 정보:
#  📌 **법원은 이대로 전세사기 가해자를 풀어주면 안됩니다!**
# 가해자들은 여전히 책임을 인정하지 않고, 법원에서는 그들의 죄에 걸맞은 처벌을 내리지 않은 상황입니다. 전세사기 피해자들에게는 전세보증금이 삶의
# [🔗 링크](https://campaigns.do/discussions/1870)
#
# 📌 **전세 사기로 보증금을 돌려받지 못하고 있습니다 현재 연락 두절이에요**
# 전세 사기로 보증금을 돌려받지 못하고 있습니다 현재 연락 두절이에요 상담사례입니다. 사기 로앤굿 변호사님들의 해결방안과 유사경험을 확인해보세요.
# [🔗 링크](https://www.lawandgood.com/posts/quotation-content/%EC%82%AC%EA%B8%B0/qc-15063)
#
# 📌 **전세사기 처벌과 임차인 보증금 회수 방법은 : 네이버 블로그**
# 또한, 금액에 따라서 가중처벌을 받고 특히 50억 원이 넘어가게 되면 최대 무기 징역형까지 가해질 수 있습니다.하지만 악성 임대인에 대한 전세사기 처벌
# [🔗 링크](https://blog.naver.com/lawyer8588/223509645527?viewType=pc)
#
# 📌 **[건설·부동산] 이른바 전세 사기에 관한 판례 동향 - 법률신문**
# 이에 따라 최근에는 전세 사기에 대해 공인중개사가 손해배상책임까지 부담하는 경우가 늘고 있습니다. 나아가 종래 임차인 스스로의 주의의무 등을
# [🔗 링크](https://www.lawtimes.co.kr/LawFirm-NewsLetter/189444)
#
# 📌 **집주인을 전세 사기로 고소할 수 있을까? 전세보증금 못 ... - YouTube**
# 전세사기를 쉽게 설명 해보자면 집주인이 처음 임대차계약을 체결할때부터 보증금을 돌려줄 능력이나 의사가 없었다는 이야기인데요.
# [🔗 링크](https://www.youtube.com/watch?v=QSOY7tk_g6o)
#
#
#
# 📜 Tavily AI 검색 요약:
#  <법률 정보>
# 법률 제목: 전세사기에 관한 형법
# 법률 조항: "전세 보증금을 반환할 능력이나 의도가 없는 상태에서 임대차 계약을 체결한 경우, 사기로 간주되어 형사 처벌을 받을 수 있습니다."
# 법률 요약: 전세사기는 임대인이 전세 보증금을 반환할 능력이나 의도가 없으면서 임대차 계약을 체결하는 행위로, 이 법은 전세사기의 정의 및 처벌 내용을 명시하고 있습니다.
#
# 법률 제목: 형법 제347조 (사기)
# 법률 조항: "사기의 경우, 피해 금액에 따라 처벌이 달라지며, 피해자가 100만원 이상을 잃은 경우 형사 처벌을 받게 됩니다."
# 법률 요약: 이 법은 사기의 처벌 기준을 정하며, 금액에 따라 다르게 처벌됩니다. 특히, 사기 금액이 100만원 이상일 경우, 형사 처벌이 부과됩니다.
#
# <관련 사례>
# 사례 제목: 전세사기 사건의 판결 사례
# 사례 요약: "2021년에 발생한 전세사기 사건에서, 피고인은 1억 원 규모의 전세 보증금을 사기쳐 유죄 판결을 받았으며, 금전적 배상 및 징역형을 선고받았습니다."
# 링크: [전세사기 사건 판결](https://www.lifein.news/news/articleView.html?idxno=16750)
#
# 사례 제목: 전세사기 피해자 배상 사례
# 사례 요약: "2022년 발생한 전세사기 사건에서, 피해자는 가해자에게 법적 배상을 청구했습니다. 법원은 피해 금액을 기준으로 배상액을 산정하며, 피해자가 입은 피해를 보상받게 했습니다."
# 링크: [전세사기 피해자 배상](http://www.gangnam.news/news/articleView.html?idxno=671)
#
# 사례 제목: 전세사기 사건의 합의 판결 사례
# 사례 요약: "2023년에 발생한 전세사기 사건에서, 피해자는 가해자와 합의를 통해 금전적 배상금을 받기로 했으며, 법원은 그 합의를 인정하여 사건을 종결했습니다."
# 링크: [전세사기 사건 합의](http://www.ikbn.news/mobile/article.html?no=155774)
#
# <예상 결과>
# 승률: "전세사기 사건의 승률은 피해 금액과 증거에 따라 다르며, 현 상황에서는 1억 원 규모의 사기로 유죄 판결을 받을 것으로 예상됩니다."
# 형량: "형량은 범죄의 심각성과 피해 금액에 따라 다르며, 일반적으로 금전적 배상과 함께 형사 처벌이 부과됩니다."
# 소요 기간: "전세사기 사건의 경우 보통 6개월에서 1년 정도 소요될 수 있으며, 피해자가 법적 배상을 청구한 경우 기간이 더 길어질 수 있습니다."
